# %%
print("hello world")
# Out:
# hello world

# %%
a=(1,2,3,4,5)
b=(31,24,55,77,89,55,99,55)

name=("adfg","sdfui","udyfjdshaf")
# print(len(name))
# print(b[0:2])

# for i in b:
#     if i==77:
#         print("it is there")
        
# print(list(b))
# print(b.count(55))

# %%
for i in b:
    if i%2==0:
        print(i)
# Out:
# 24

# %%
for i in range(len(b)):
    print(b[i])
    if b[i]%2==0:
        print(b[i])
# Out:
# 31
# 24
# 24
# 55
# 77
# 89
# 55
# 99
# 55

# %%
#dict concepts
student_records={
    "name":"abdg",
    "class":10,
    "roll_no":36,


}



print(student_records["class"])
print(student_records.update({"result":"pass"}))
print(student_records)
# Out:
# 10
# None
# {'name': 'abdg', 'class': 10, 'roll_no': 36, 'result': 'pass'}

# %%
student_records["result"]="fail"

# %%
print(student_records)
# Out:
# {'name': 'abdg', 'class': 10, 'roll_no': 36, 'result': 'fail'}

# %%
for i in student_records.items():
    print(i)
# Out:
# ('name', 'abdg')
# ('class', 10)
# ('roll_no', 36)
# ('result', 'fail')

# %%
for k,v in student_records.items():
    print(k,v)
# Out:
# name abdg
# class 10
# roll_no 36
# result fail

# %%
cricket_record={}
name=input("Enter the name :")
age=int(input("Enter the age :"))
skill=input("batting or bowling")

cricket_record["name"]=name
cricket_record["age"]=age
cricket_record["skill"]=skill


print(cricket_record)
# Out:
# {'name': 'sfdsfdg', 'age': 32, 'skill': 'batting'}

# %%
cricket_record["bench"]="yes or no"
print(cricket_record)
# Out:
# {'name': 'sfdsfdg', 'age': 32, 'skill': 'batting', 'bench': 'yes or no'}

# %%
word="welcome to python programing"
print(word[::-1])
# Out:
# gnimargorp nohtyp ot emoclew

# %%
word[:10]
# Out:
# 'welcome to'

# %%
word[::5]
# Out:
# 'wm ooi'

# %%
"""17. Create a 3x3 matrix
Expected Output: [[0, 1, 2], [3, 4, 5], [6, 7, 8]]"""

nested_list=[
    [0,1,2,3],
    [5,6,7],
    [8,9,10]
    ]

# %%
print(nested_list[0][::-1])
print(nested_list[1])
# Out:
# [3, 2, 1, 0]
# [5, 6, 7]
